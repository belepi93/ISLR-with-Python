# %% [markdown]
# # Chapter9 - Exercise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import label_binarize, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report

from scipy.stats import multivariate_normal

% matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
def plot_svc(svc, X, y, h=0.02, pad=0.25):
    x_min, x_max = X[:, 0].min()-pad, X[:, 0].max()+pad
    y_min, y_max = X[:, 1].min()-pad, X[:, 1].max()+pad
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min,y_max, h))
    Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.2)
    
    plt.scatter(X[:,0], X[:, 1], s=70, c=y, cmap=plt.cm.Paired)
    # Support vectors indicated in plot by vertical lines
    sv = svc.support_vectors_
    plt.scatter(sv[:,0], sv[:,1], c='k', marker='|', s=100, linewidths='1')
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.show()
    print('Number of support vectors: ', svc.support_.size)

# %% [markdown]
# # 4
# ## (a)

# %%
np.random.seed(1)

# %%
rv1 = multivariate_normal([0,0], [[1,0],[0,1]])
rv2 = multivariate_normal([0,2.5], [[1,0],[0,1]])
rv3 = multivariate_normal([2.5,0], [[1,0],[0,1]])
rv4 = multivariate_normal([2.5,2.5], [[1,0],[0,1]])

# %%
X = np.vstack([rv1.rvs(25),rv2.rvs(25),rv3.rvs(25),rv4.rvs(25)])
y = np.repeat([0,1], [75,25])

# %%
plt.scatter(X[:,0], X[:,1], s=70, c=y, cmap=plt.cm.Set1);

# %% [markdown]
# **Linear**

# %%
svc = SVC(C=1, kernel='linear')
svc.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_svc(svc, X, y)
# Out:
# Number of support vectors:  24

# %%
cm = confusion_matrix(svc.predict(X), y)
cm_df = pd.DataFrame(cm, index=svc.classes_, columns=svc.classes_)
cm_df.index.name = 'Predicted'
cm_df.columns.name = 'True'
print(cm_df)
# Out:
# True        0   1
# Predicted
# 0          72   6
# 1           3  19

# %% [markdown]
# **Radial Kernel**

# %%
svc = SVC(C=1, kernel='rbf')
svc.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_svc(svc, X, y)
# Out:
# Number of support vectors:  34

# %%
cm = confusion_matrix(svc.predict(X), y)
cm_df = pd.DataFrame(cm, index=svc.classes_, columns=svc.classes_)
cm_df.index.name = 'Predicted'
cm_df.columns.name = 'True'
print(cm_df)
# Out:
# True        0   1
# Predicted
# 0          74   6
# 1           1  19

# %% [markdown]
# **Polynomial with degree 3**

# %%
svc = SVC(C=1, kernel='poly', degree=3)
svc.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_svc(svc, X, y)
# Out:
# Number of support vectors:  17

# %%
cm = confusion_matrix(svc.predict(X), y)
cm_df = pd.DataFrame(cm, index=svc.classes_, columns=svc.classes_)
cm_df.index.name = 'Predicted'
cm_df.columns.name = 'True'
print(cm_df)
# Out:
# True        0   1
# Predicted
# 0          74   5
# 1           1  20

# %% [markdown]
# # 5
# ## (a), (b)

# %%
np.random.seed(1)
X = np.random.randn(500,2)
y = np.where(X[:,0] ** 2 - X[:,1] ** 2 > 0, 1, 0)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Set1, alpha=0.8);

# %% [markdown]
# ## (c)

# %%
clf = LogisticRegression()
clf.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## (d)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)
pred = clf.predict(X_train)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(X_train[:,0], X_train[:,1], c=pred, cmap=plt.cm.Set1, alpha=0.8);

# %% [markdown]
# ## (e)

# %%
X_poly = PolynomialFeatures(2, include_bias = False).fit_transform(X)
X_train_poly = PolynomialFeatures(2, include_bias = False).fit_transform(X_train)
X_test_poly = PolynomialFeatures(2, include_bias = False).fit_transform(X_test)

# %%
clf2 = LogisticRegression()
clf2.fit(X_poly, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## (f)

# %%
pred = clf2.predict(X_train_poly)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(X_train_poly[:,0], X_train_poly[:,1], c=pred, cmap=plt.cm.Set1, alpha=0.8);

# %% [markdown]
# ## (g)

# %%
svc = SVC(C=1, kernel='linear')
svc.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_svc(svc, X, y)
# Out:
# Number of support vectors:  475

# %%
pred = svc.predict(X_train)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(X_train[:,0], X_train[:,1], c=pred, cmap=plt.cm.Set1, alpha=0.8);

# %% [markdown]
# ## (h)

# %%
svc = SVC(C=1, kernel='rbf')
svc.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plot_svc(svc, X, y)
# Out:
# Number of support vectors:  174

# %%
pred = svc.predict(X_train)

# %%
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(X_train[:,0], X_train[:,1], c=pred, cmap=plt.cm.Set1, alpha=0.8);

# %% [markdown]
# # 6
# ## (a)

# %%
np.random.seed(30)
rv1 = multivariate_normal([0,0], [[1,-0.9],[-0.9,1]])
rv2 = multivariate_normal([0.7,0.7], [[1,-0.9],[-0.9,1]])

# %%
X = np.vstack([rv1.rvs(300),rv2.rvs(300)])
y = np.repeat([0,1], [300,300])

# %%
plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.Paired, alpha=0.6);

# %% [markdown]
# ## (b)

# %%
np.random.seed(5)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3)

# %%
C_list = np.hstack([np.linspace(0.001, 0.01, 10), np.linspace(0.01, 0.1, 10), np.linspace(0.1, 1, 10),
    np.linspace(1, 10, 10), np.linspace(10, 100, 10), np.linspace(100, 1000, 10), np.linspace(1000,10000,10)])

# %%
train_errors = []
cv_errors = []
kf_10 = KFold(n_splits = 10, shuffle=True)

for C in C_list:
    # CV errors
    svc = SVC(C=C, kernel='linear')
    score = -1*cross_val_score(svc, X, y, cv=kf_10,
                           scoring='neg_mean_squared_error').mean()
    cv_errors.append(score)
    
    # Training Errors
    svc = SVC(C=C, kernel='linear')
    svc.fit(X_train, y_train)
    train_errors.append(1 - svc.score(X_train, y_train))

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(range(len(cv_errors)), cv_errors)
ax.plot(np.argmin(cv_errors), np.min(cv_errors), 'bx', ms=10)
ax.plot(range(len(train_errors)), train_errors)
ax.plot(np.argmin(train_errors), np.min(train_errors), 'rx', ms=10)
ax.set_ylim(0.06,0.12);

# %% [markdown]
# ## (c)

# %%
test_errors = []
for C in C_list:
    # Test Errors
    svc = SVC(C=C, kernel='linear')
    svc.fit(X_train, y_train)
    test_errors.append(1 - svc.score(X_test, y_test))

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(range(len(test_errors)), test_errors)
ax.plot(np.argmin(test_errors), np.min(test_errors), 'rx', ms=10)
ax.set_ylim(0.06,0.12);

# %% [markdown]
# # 7
# ## (a)

# %%
df = pd.read_csv('../Data/Auto.csv', na_values=['?']).drop('name', axis=1).dropna()

# %%
df['mpg'] = np.where(df['mpg'] > df['mpg'].median(), 1, 0)

# %%
df.head()
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    0          8         307.0       130.0    3504          12.0    70
# 1    0          8         350.0       165.0    3693          11.5    70
# 2    0          8         318.0       150.0    3436          11.0    70
# 3    0          8         304.0       150.0    3433          12.0    70
# 4    0          8         302.0       140.0    3449          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
X = df.drop('mpg', axis=1)
y = df['mpg']

# %% [markdown]
# ## (b)

# %%
C_list = np.array([0.001, 0.01, 0.1, 1, 10, 100, 1000])

# %%
cv_errors = []
kf_10 = KFold(n_splits = 10, shuffle=True)

for C in C_list:
    # CV errors
    svc = SVC(C=C, kernel='linear')
    score = -1*cross_val_score(svc, X, y, cv=kf_10,
                           scoring='neg_mean_squared_error').mean()
    cv_errors.append(score)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(range(len(cv_errors)), cv_errors)
ax.plot(np.argmin(cv_errors), np.min(cv_errors), 'rx', ms=10);

# %% [markdown]
# ## (c)

# %% [markdown]
# **rbf**

# %%
cv_errors = []
kf_10 = KFold(n_splits = 10, shuffle=True)

for C in C_list:
    # CV errors
    svc = SVC(C=C, kernel='rbf')
    score = -1*cross_val_score(svc, X, y, cv=kf_10,
                           scoring='neg_mean_squared_error').mean()
    cv_errors.append(score)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.plot(range(len(cv_errors)), cv_errors)
ax.plot(np.argmin(cv_errors), np.min(cv_errors), 'rx', ms=10);

# %% [markdown]
# **polynomial with degree 2**
#
# I tried this thing, but this takes too long so i skipped this.

# %% [markdown]
# # 8
# ## (a)

# %%
df = pd.read_csv("../Data/OJ.csv").drop('Unnamed: 0', axis=1)

# %%
df['Store7'] = pd.factorize(df['Store7'])[0]
df['Purchase'] = pd.factorize(df['Purchase'])[0]

# %%
df.head()
# Out:
#    Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0         0             237        1     1.75     1.99    0.00     0.0
# 1         0             239        1     1.75     1.99    0.00     0.3
# 2         0             245        1     1.86     2.09    0.17     0.0
# 3         1             227        1     1.69     1.69    0.00     0.0
# 4         0             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff  \
# 0          0          0  0.500000         1.99         1.75       0.24
# 1          0          1  0.600000         1.69         1.75      -0.06
# 2          0          0  0.680000         2.09         1.69       0.40
# 3          0          0  0.400000         1.69         1.69       0.00
# 4          0          0  0.956535         1.69         1.69       0.00
#
#    Store7  PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0       0   0.000000   0.000000           0.24      1
# ...

# %%
X = df.drop('Purchase', axis=1)
y = df['Purchase']

# %%
np.random.seed(1)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 1 - 800.5/len(df))

# %%
len(X_train)
# Out:
# 800

# %% [markdown]
# ## (b)

# %%
svc = SVC(C=0.01, kernel='linear')
svc.fit(X,y)
# Out:
# SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ## (c)

# %%
svc.fit(X_train, y_train)
print("Training Error:", 1- svc.score(X_train, y_train))
print("Test Error:", 1-svc.score(X_test, y_test))
# Out:
# Training Error: 0.31
# Test Error: 0.359259259259

# %% [markdown]
# ## (d)

# %%
C_list = [0.01, 0.1, 1, 10]

# %%
cv_errors=[]
kf_10 = KFold(n_splits = 10)

for C in C_list:
    # CV errors
    svc = SVC(C=C, kernel='linear')
    score = -1*cross_val_score(svc, X, y, cv=kf_10,
                           scoring='neg_mean_squared_error').mean()
    cv_errors.append(score)

# %%
plt.plot(cv_errors);

# %%
C_list[np.argmin(cv_errors)]
# Out:
# 1

# %% [markdown]
# ## (e)

# %%
svc = SVC(C=1, kernel='linear')
svc.fit(X_train,y_train)

print("Training Error:", 1 - svc.score(X_train, y_train))
print("Test Error:", 1 - svc.score(X_test, y_test))
# Out:
# Training Error: 0.165
# Test Error: 0.17037037037

# %% [markdown]
# ## (f)

# %%
svc = SVC(C=0.01, kernel='rbf')
svc.fit(X,y)

svc.fit(X_train, y_train)
print("Training Error:", 1- svc.score(X_train, y_train))
print("Test Error:", 1-svc.score(X_test, y_test))

cv_errors=[]
kf_10 = KFold(n_splits = 10)

for C in C_list:
    # CV errors
    svc = SVC(C=C, kernel='rbf')
    score = -1*cross_val_score(svc, X, y, cv=kf_10,
                           scoring='neg_mean_squared_error').mean()
    cv_errors.append(score)
# Out:
# Training Error: 0.38
# Test Error: 0.418518518519

# %%
plt.plot(cv_errors);

# %%
C_list[np.argmin(cv_errors)]
# Out:
# 10

# %%
svc = SVC(C=10, kernel='linear')
svc.fit(X_train,y_train)

print("Training Error:", 1 - svc.score(X_train, y_train))
print("Test Error:", 1 - svc.score(X_test, y_test))
# Out:
# Training Error: 0.16125
# Test Error: 0.181481481481

# %% [markdown]
# ## (g)
# I don't know why, but SVC with polynomials don't work well for me..

# %%
#svc = SVC(C=0.01, kernel='poly', degree=2)
#svc.fit(X,y)

#svc.fit(X_train, y_train)
#print("Training Error:", 1- svc.score(X_train, y_train))
#print("Test Error:", 1-svc.score(X_test, y_test))

#cv_errors=[]
#kf_10 = KFold(n_splits = 10)

#for C in C_list:
#    # CV errors
#    svc = SVC(C=C, kernel='poly', degree=2)
#    score = -1*cross_val_score(svc, X, y, cv=kf_10,
#                           scoring='neg_mean_squared_error').mean()
#    cv_errors.append(score)
# Out:
# Training Error: 0.16125
# Test Error: 0.177777777778

# %%
#plt.plot(cv_errors);

# %%
#C_list[np.argmin(cv_errors)]
# Out:
# 10

# %%
#svc = SVC(C=10, kernel='linear')
#svc.fit(X_train,y_train)

#print("Training Error:", 1 - svc.score(X_train, y_train))
#print("Test Error:", 1 - svc.score(X_test, y_test))
# Out:
# Training Error: 0.16125
# Test Error: 0.181481481481
